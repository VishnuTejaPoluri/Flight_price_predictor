# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Exploring Data

# %%
df = pd.read_csv('Clean_Dataset.csv')
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
df.airline.value_counts()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64

# %%
df.source_city.value_counts()
# Out:
# source_city
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: count, dtype: int64

# %%
df.destination_city.value_counts()
# Out:
# destination_city
# Mumbai       59097
# Delhi        57360
# Bangalore    51068
# Kolkata      49534
# Hyderabad    42726
# Chennai      40368
# Name: count, dtype: int64

# %%
df.departure_time.value_counts()
# Out:
# departure_time
# Morning          71146
# Early_Morning    66790
# Evening          65102
# Night            48015
# Afternoon        47794
# Late_Night        1306
# Name: count, dtype: int64

# %%
df.stops.value_counts()
# Out:
# stops
# one            250863
# zero            36004
# two_or_more     13286
# Name: count, dtype: int64

# %%
df.arrival_time.value_counts()
# Out:
# arrival_time
# Night            91538
# Evening          78323
# Morning          62735
# Afternoon        38139
# Early_Morning    15417
# Late_Night       14001
# Name: count, dtype: int64

# %%
df['class'].value_counts()
# Out:
# class
# Economy     206666
# Business     93487
# Name: count, dtype: int64

# %%
df['duration'].value_counts()
# Out:
# duration
# 2.17     4242
# 2.25     4036
# 2.75     2879
# 2.08     2755
# 2.83     2323
#          ...
# 37.17       1
# 38.75       1
# 38.50       1
# 36.25       1
# 41.50       1
# Name: count, Length: 476, dtype: int64

# %%
df['duration'].min()
# Out:
# 0.83

# %%
df['duration'].max()
# Out:
# 49.83

# %%
df['duration'].median()
# Out:
# 11.25

# %% [markdown]
# ### Data Preprocessing

# %%
df = df.drop('Unnamed: 0',axis = 1)
df = df.drop('flight',axis = 1)
df['class'] = df['class'].apply(lambda x: 1 if x=='Business' else 0)
df
# Out:
#          airline source_city departure_time stops   arrival_time  \
# 0       SpiceJet       Delhi        Evening  zero          Night
# 1       SpiceJet       Delhi  Early_Morning  zero        Morning
# 2        AirAsia       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara       Delhi        Morning  zero      Afternoon
# 4        Vistara       Delhi        Morning  zero        Morning
# ...          ...         ...            ...   ...            ...
# 300148   Vistara     Chennai        Morning   one        Evening
# 300149   Vistara     Chennai      Afternoon   one          Night
# 300150   Vistara     Chennai  Early_Morning   one          Night
# 300151   Vistara     Chennai  Early_Morning   one        Evening
# 300152   Vistara     Chennai        Morning   one        Evening
#
#        destination_city  class  duration  days_left  price
# 0                Mumbai      0      2.17          1   5953
# 1                Mumbai      0      2.33          1   5953
# ...

# %%
df.stops = pd.factorize(df.stops)[0]

# %%
df.stops.value_counts()
# Out:
# stops
# 1    250863
# 0     36004
# 2     13286
# Name: count, dtype: int64

# %%
df = df.join(pd.get_dummies(df.airline,dtype = int,prefix = 'airline')).drop('airline',axis=1)
df = df.join(pd.get_dummies(df.source_city,dtype = int,prefix = 'src')).drop('source_city',axis=1)
df = df.join(pd.get_dummies(df.destination_city,dtype = int,prefix = 'dst')).drop('destination_city',axis=1)
df = df.join(pd.get_dummies(df.arrival_time,dtype = int,prefix = 'arr_time')).drop('arrival_time',axis=1)
df = df.join(pd.get_dummies(df.departure_time,dtype = int,prefix = 'dep_time')).drop('departure_time',axis=1)
df
# Out:
#         stops  class  duration  days_left  price  airline_AirAsia  \
# 0           0      0      2.17          1   5953                0
# 1           0      0      2.33          1   5953                0
# 2           0      0      2.17          1   5956                1
# 3           0      0      2.25          1   5955                0
# 4           0      0      2.33          1   5955                0
# ...       ...    ...       ...        ...    ...              ...
# 300148      1      1     10.08         49  69265                0
# 300149      1      1     10.42         49  77105                0
# 300150      1      1     13.83         49  79099                0
# 300151      1      1     10.00         49  81585                0
# 300152      1      1     10.08         49  81585                0
#
#         airline_Air_India  airline_GO_FIRST  airline_Indigo  airline_SpiceJet  \
# 0                       0                 0               0                 1
# ...

# %% [markdown]
# ### Training Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

x = df.drop('price',axis=1)
y = df['price']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
reg = RandomForestRegressor(n_jobs = -1)
reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
reg.score(x_test,y_test)
# Out:
# 0.9852573327354837

# %%
import math
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = reg.predict(x_test)
print('r2: ',r2_score(y_test,y_pred))
print('MAE: ', mean_absolute_error(y_test,y_pred))
print('MSE: ',mean_squared_error(y_test,y_pred))
print('RMSE ',math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2:  0.9852573327354837
# MAE:  1084.7234739519504
# MSE:  7615782.6105785
# RMSE  2759.670743146454

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test,y_pred)
plt.title('Predicetd vs Actual')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
# Out:
# Text(0, 0.5, 'Predicted values')

# %%
df
# Out:
#         stops  class  duration  days_left  price  airline_AirAsia  \
# 0           0      0      2.17          1   5953                0
# 1           0      0      2.33          1   5953                0
# 2           0      0      2.17          1   5956                1
# 3           0      0      2.25          1   5955                0
# 4           0      0      2.33          1   5955                0
# ...       ...    ...       ...        ...    ...              ...
# 300148      1      1     10.08         49  69265                0
# 300149      1      1     10.42         49  77105                0
# 300150      1      1     13.83         49  79099                0
# 300151      1      1     10.00         49  81585                0
# 300152      1      1     10.08         49  81585                0
#
#         airline_Air_India  airline_GO_FIRST  airline_Indigo  airline_SpiceJet  \
# 0                       0                 0               0                 1
# ...
